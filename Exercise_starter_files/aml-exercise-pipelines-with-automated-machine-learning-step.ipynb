# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# WARNING - Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# ws-azureml
# rg-ai
# westus2
# e36180a3-997b-4765-87a8-36f70eefc1fb

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'Bankmarketing-exp'
project_folder = './bankmarketing-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: Bankmarketing-exp,
# Workspace: ws-azureml)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded...........................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bankmarketing Dataset"
description_text = "Bankmarketing Dataset for Udacity AZML Engineer Project 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `time_column_name` has to be `cnt` for example.

# %%
automl_settings = {
    "experiment_timeout_hours" : 0.3,
    "enable_early_stopping" : True,
    "iteration_timeout_minutes": 5,
    "max_concurrent_iterations": 4,
    "max_cores_per_iteration": -1,
    "n_cross_validations": 3,
    "primary_metric": 'accuracy',
    "featurization": 'auto',
    "verbosity": logging.INFO,
}

automl_config = AutoMLConfig(task = 'classification',
                             debug_log = 'automl_errors.log',
                             compute_target=compute_target,
                             path = project_folder,
                             training_data = dataset,
                             label_column_name = "y",
                             **automl_settings
                            )

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 4,
    "primary_metric" : 'AUC_weighted',
    "n_cross_validations": 5
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             time_column_name="date", 
                             label_column_name="y",  
                             path = project_folder,
                             enable_early_stopping= True,
                             #featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [539f1830][f99c9024-bbd7-479d-abee-a408542091b2], (This step will run and generate new outputs)
# Submitted PipelineRun 3cfab968-d0bf-464c-b70c-e95c7fc60710
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bankmarketing-exp/runs/3cfab968-d0bf-464c-b70c-e95c7fc60710?wsid=/subscriptions/e36180a3-997b-4765-87a8-36f70eefc1fb/resourcegroups/rg-ai/workspaces/ws-azureml

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 3cfab968-d0bf-464c-b70c-e95c7fc60710
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bankmarketing-exp/runs/3cfab968-d0bf-464c-b70c-e95c7fc60710?wsid=/subscriptions/e36180a3-997b-4765-87a8-36f70eefc1fb/resourcegroups/rg-ai/workspaces/ws-azureml
# PipelineRun Status: Running
#
#
# StepRunId: 366f1870-b3d9-40dc-8b9b-c3686597df46
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bankmarketing-exp/runs/366f1870-b3d9-40dc-8b9b-c3686597df46?wsid=/subscriptions/e36180a3-997b-4765-87a8-36f70eefc1fb/resourcegroups/rg-ai/workspaces/ws-azureml
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '366f1870-b3d9-40dc-8b9b-c3686597df46', 'target': 'cpu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-12-21T11:47:54.339266Z', 'endTimeUtc': '2020-12-21T12:30:59.780276Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'af5b8849-57b4-4c2a-8313-691a06c0994b', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'f99c9024-bbd7-479d-abee-a408542091b2', 'azureml.nodeid': '539f1830', 'azureml.pipelinerunid': '3cfab968-d0bf-464c-b70c-e95c7fc60710', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': '300', 'acquisition_parameter': '0', 'num_cross_validation': '3', 'target': 'cpu-cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "e36180a3-997b-4765-87a8-36f70eefc1fb", "resource_group": "rg-ai", "workspace_name": "ws-azureml", "region": "westus2", "compute_target": "cpu-cluster", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": 3, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": -1, "max_concurrent_iterations": 4, "iteration_timeout_minutes": 5, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 18, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["SGD", "DecisionTree", "AveragedPerceptronClassifier", "BernoulliNaiveBayes", "LinearSVM", "GradientBoosting", "LogisticRegression", "KNN", "XGBoostClassifier", "ExtremeRandomTrees", "SVM", "TensorFlowLinearClassifier", "MultinomialNaiveBayes", "TensorFlowDNN", "RandomForest", "LightGBM"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"a32f42dc-1c90-4155-941b-cb1de463b7e8\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'af5b8849-57b4-4c2a-8313-691a06c0994b', 'SetupRunId': '366f1870-b3d9-40dc-8b9b-c3686597df46_setup', 'SetupRunContainerId': 'dcid.366f1870-b3d9-40dc-8b9b-c3686597df46_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '366f1870-b3d9-40dc-8b9b-c3686597df46_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features": 132, "dat ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3cfab968-d0bf-464c-b70c-e95c7fc60710', 'status': 'Completed', 'startTimeUtc': '2020-12-21T11:47:24.800701Z', 'endTimeUtc': '2020-12-21T12:31:27.412722Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://wsazureml4184061445.blob.core.windows.net/azureml/ExperimentRun/dcid.3cfab968-d0bf-464c-b70c-e95c7fc60710/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=yYF%2FU9EdWyAzJNTLDVpQKhArCp4FkCNB5zNa%2BdJ7Fjs%3D&st=2020-12-21T11%3A38%3A32Z&se=2020-12-21T19%3A48%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://wsazureml4184061445.blob.core.windows.net/azureml/ExperimentRun/dcid.3cfab968-d0bf-464c-b70c-e95c7fc60710/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=4rW2NdQxMKsSxNR3py%2FvwRLajI%2B3Lifdk3vi6B0%2Fpe0%3D&st=2020-12-21T11%3A38%3A32Z&se=2020-12-21T19%3A48%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://wsazureml4184061445.blob.core.windows.net/azureml/ExperimentRun/dcid.3cfab968-d0bf-464c-b70c-e95c7fc60710/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=BJMEqw5W4Fu7gtSXgfW%2BzslUnp8aYvUa9MyeZ%2FZepmc%3D&st=2020-12-21T11%3A38%3A32Z&se=2020-12-21T19%3A48%3A32Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/366f1870-b3d9-40dc-8b9b-c3686597df46/metrics_data
# Downloaded azureml/366f1870-b3d9-40dc-8b9b-c3686597df46/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
# l_score_weighted                              [0.9149620304190345]
# precision_score_macro                              [0.8005020309194055]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_7  \
# AUC_weighted                                       [0.9464079174446768]
# recall_score_macro                                 [0.7433063781541311]
# precision_score_weighted                           [0.9081878001882303]
# average_precision_score_micro                      [0.9812084580863049]
# precision_score_micro                              [0.9143246652107098]
# weighted_accuracy                                   [0.956823385006409]
# accuracy                                           [0.9143246652107098]
# f1_score_weighted                                  [0.9103533056392737]
# AUC_macro                                          [0.9464079174446768]
# matthews_correlation                               [0.5345909170863251]
# recall_score_micro                                 [0.9143246652107098]
# average_precision_score_macro                      [0.8235185680836768]
# AUC_micro                                          [0.9804152043566642]
# average_precision_score_weighted                   [0.9550234454297165]
# f1_score_macro                                     [0.7650324592805559]
# balanced_accuracy                                  [0.7433063781541311]
# log_loss                                          [0.17637738359708577]
# f1_score_micro                                     [0.9143246652107099]
# norm_macro_recall                                 [0.48661275630826234]
# recall_score_weighted                              [0.9143246652107098]
# precision_score_macro                              [0.7938067641636609]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_0  \
# AUC_weighted                                       [0.9488596681107301]
# recall_score_macro                                 [0.7529936178764652]
# precision_score_weighted                           [0.9100523900603221]
# average_precision_score_micro                      [0.9818350863116239]
# precision_score_micro                              [0.9151137137782758]
# weighted_accuracy                                  [0.9554038231981897]
# accuracy                                           [0.9151137137782758]
# f1_score_weighted                                  [0.9119766985795604]
# AUC_macro                                          [0.9488596681107301]
# matthews_correlation                               [0.5453093845139412]
# recall_score_micro                                 [0.9151137137782758]
# average_precision_score_macro                      [0.8265505203192661]
# AUC_micro                                          [0.9810163422947249]
# average_precision_score_weighted                   [0.9560291488081631]
# f1_score_macro                                     [0.7711353005076105]
# balanced_accuracy                                  [0.7529936178764652]
# log_loss                                          [0.17296231855547273]
# f1_score_micro                                     [0.9151137137782758]
# norm_macro_recall                                  [0.5059872357529306]
# recall_score_weighted                              [0.9151137137782758]
# precision_score_macro                              [0.7939948392597028]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_3  \
# AUC_weighted                                       [0.8772722476007965]
# recall_score_macro                                                [0.5]
# precision_score_weighted                           [0.7884599222029637]
# average_precision_score_micro                      [0.9617627215616281]
# precision_score_micro                              [0.8879513897938054]
# weighted_accuracy                                  [0.9843221467681259]
# accuracy                                           [0.8879513897938054]
# f1_score_weighted                                  [0.8352527577845065]
# AUC_macro                                          [0.8772722476007965]
# matthews_correlation                                              [0.0]
# recall_score_micro                                 [0.8879513897938054]
# average_precision_score_macro                           [0.72077921707]
# AUC_micro                                          [0.9630209958117725]
# average_precision_score_weighted                   [0.9216097197225976]
# f1_score_macro                                     [0.4703250109015522]
# balanced_accuracy                                                 [0.5]
# log_loss                                           [0.2722296125855856]
# f1_score_micro                                     [0.8879513897938054]
# norm_macro_recall                                                 [0.0]
# recall_score_weighted                              [0.8879513897938054]
# precision_score_macro                              [0.4439756948969027]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_8  \
# AUC_weighted                                       [0.9445235390245529]
# recall_score_macro                                 [0.7455382769079586]
# precision_score_weighted                           [0.9068608288600264]
# average_precision_score_micro                      [0.9804750420188041]
# precision_score_micro                              [0.9122002637239123]
# weighted_accuracy                                  [0.9536157783933611]
# accuracy                                           [0.9122002637239123]
# f1_score_weighted                                  [0.9089380516827164]
# AUC_macro                                          [0.9445235390245529]
# matthews_correlation                               [0.5293146491501014]
# recall_score_micro                                 [0.9122002637239123]
# average_precision_score_macro                      [0.8172821344612095]
# AUC_micro                                          [0.9797255624445583]
# average_precision_score_weighted                   [0.9533793892448514]
# f1_score_macro                                     [0.7631725831702877]
# balanced_accuracy                                  [0.7455382769079586]
# log_loss                                          [0.20213240137808067]
# f1_score_micro                                     [0.9122002637239123]
# norm_macro_recall                                 [0.49107655381591725]
# recall_score_weighted                              [0.9122002637239123]
# precision_score_macro                              [0.7854011468951283]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_6  \
# AUC_weighted                                       [0.9355804903163362]
# recall_score_macro                                 [0.6831104113315316]
# precision_score_weighted                           [0.8957839712857703]
# average_precision_score_micro                      [0.9779547997522583]
# precision_score_micro                              [0.9079210942369453]
# weighted_accuracy                                  [0.9637763565339647]
# accuracy                                           [0.9079210942369453]
# f1_score_weighted                                  [0.8977822018181003]
# AUC_macro                                          [0.9355804903163362]
# matthews_correlation                              [0.45847565855114897]
# recall_score_micro                                 [0.9079210942369453]
# average_precision_score_macro                      [0.7957957054047098]
# AUC_micro                                          [0.9769922064614237]
# average_precision_score_weighted                   [0.9476533622752958]
# f1_score_macro                                     [0.7190596249994655]
# balanced_accuracy                                  [0.6831104113315316]
# log_loss                                          [0.19712553608881098]
# f1_score_micro                                     [0.9079210942369453]
# norm_macro_recall                                  [0.3662208226630633]
# recall_score_weighted                              [0.9079210942369453]
# precision_score_macro                              [0.7873751685537762]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_9  \
# AUC_weighted                                       [0.9477814933408683]
# recall_score_macro                                 [0.7446890245052792]
# precision_score_weighted                           [0.9088757862873688]
# average_precision_score_micro                      [0.9815757113546834]
# precision_score_micro                              [0.9150530470660289]
# weighted_accuracy                                  [0.9573941906345195]
# accuracy                                           [0.9150530470660289]
# f1_score_weighted                                  [0.9110489972790782]
# AUC_macro                                          [0.9477814881427221]
# matthews_correlation                               [0.5380472724392833]
# recall_score_micro                                 [0.9150530470660289]
# average_precision_score_macro                      [0.8248550952012891]
# AUC_micro                                          [0.9807510838067898]
# average_precision_score_weighted                   [0.9555307225563832]
# f1_score_macro                                     [0.7667290031324087]
# balanced_accuracy                                  [0.7446890245052792]
# log_loss                                          [0.17510928267977802]
# f1_score_micro                                     [0.9150530470660289]
# norm_macro_recall                                  [0.4893780490105583]
# recall_score_weighted                              [0.9150530470660289]
# precision_score_macro                               [0.795914018230675]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_15  \
# AUC_weighted                                        [0.9492311286500676]
# recall_score_macro                                  [0.7406172038842036]
# precision_score_weighted                            [0.9090313971650184]
# average_precision_score_micro                       [0.9819577716820759]
# precision_score_micro                               [0.9154475602973958]
# weighted_accuracy                                   [0.9589180622380234]
# accuracy                                            [0.9154475602973958]
# f1_score_weighted                                   [0.9108741541970254]
# AUC_macro                                           [0.9492311286500676]
# matthews_correlation                                [0.5368350357800966]
# recall_score_micro                                  [0.9154475602973958]
# average_precision_score_macro                       [0.8290301807545052]
# AUC_micro                                            [0.981152715050535]
# average_precision_score_weighted                    [0.9566102393415129]
# f1_score_macro                                      [0.7650112001722427]
# balanced_accuracy                                   [0.7406172038842036]
# log_loss                                           [0.19391190329425043]
# f1_score_micro                                      [0.9154475602973958]
# norm_macro_recall                                   [0.4812344077684072]
# recall_score_weighted                               [0.9154475602973958]
# precision_score_macro                               [0.8001324634191662]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_10  \
# AUC_weighted                                        [0.9419239751112438]
# recall_score_macro                                  [0.7419411276893001]
# precision_score_weighted                             [0.907261943458549]
# average_precision_score_micro                       [0.9797020921190462]
# precision_score_micro                               [0.9133534755880975]
# weighted_accuracy                                   [0.9559778260895936]
# accuracy                                            [0.9133534755880975]
# f1_score_weighted                                   [0.9093835337556251]
# AUC_macro                                           [0.9419239751112438]
# matthews_correlation                                [0.5300197614486514]
# recall_score_micro                                  [0.9133534755880975]
# average_precision_score_macro                        [0.814006670581043]
# AUC_micro                                           [0.9792839613035361]
# average_precision_score_weighted                    [0.9520286444155183]
# f1_score_macro                                      [0.7627009631934732]
# balanced_accuracy                                   [0.7419411276893001]
# log_loss                                            [0.3162375432501525]
# f1_score_micro                                      [0.9133534755880975]
# norm_macro_recall                                  [0.48388225537860025]
# recall_score_weighted                               [0.9133534755880975]
# precision_score_macro                               [0.7906539381539809]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_2  \
# AUC_weighted                                       [0.9104277333852586]
# recall_score_macro                                  [0.550931711259371]
# precision_score_weighted                           [0.8838616057569765]
# average_precision_score_micro                      [0.9707397369407694]
# precision_score_micro                              [0.8962062736299276]
# weighted_accuracy                                  [0.9819792452516497]
# accuracy                                           [0.8962062736299276]
# f1_score_weighted                                  [0.8593557193857707]
# AUC_macro                                          [0.9104277333852587]
# matthews_correlation                               [0.2569312451273454]
# recall_score_micro                                 [0.8962062736299276]
# average_precision_score_macro                      [0.7579198095925528]
# AUC_micro                                          [0.9698477481898246]
# average_precision_score_weighted                    [0.936035294747401]
# f1_score_macro                                     [0.5643161269049592]
# balanced_accuracy                                   [0.550931711259371]
# log_loss                                           [0.2342123273115387]
# f1_score_micro                                     [0.8962062736299276]
# norm_macro_recall                                 [0.10186342251874196]
# recall_score_weighted                              [0.8962062736299276]
# precision_score_macro                              [0.8338797795371496]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_14  \
# AUC_weighted                                        [0.9489280409293599]
# recall_score_macro                                  [0.7463365078029701]
# precision_score_weighted                            [0.9102188298143092]
# average_precision_score_micro                       [0.9819473265438655]
# precision_score_micro                                 [0.91626701406179]
# weighted_accuracy                                   [0.9585055507314629]
# accuracy                                              [0.91626701406179]
# f1_score_weighted                                   [0.9121736348362545]
# AUC_macro                                           [0.9489280301275037]
# matthews_correlation                                [0.5440493243216368]
# recall_score_micro                                    [0.91626701406179]
# average_precision_score_macro                       [0.8289664260757369]
# AUC_micro                                           [0.9811445955135034]
# average_precision_score_weighted                    [0.9565618081649268]
# f1_score_macro                                      [0.7693510100608093]
# balanced_accuracy                                   [0.7463365078029701]
# log_loss                                           [0.19226481405143084]
# f1_score_micro                                        [0.91626701406179]
# norm_macro_recall                                   [0.4926730156059403]
# recall_score_weighted                                 [0.91626701406179]
# precision_score_macro                               [0.8007418526267003]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_4  \
# AUC_weighted                                       [0.8905893690541854]
# recall_score_macro                                 [0.7967870928685202]
# precision_score_weighted                           [0.8972057458578212]
# average_precision_score_micro                      [0.8764782298285279]
# precision_score_micro                              [0.8050679561122701]
# weighted_accuracy                                  [0.8072045127585766]
# accuracy                                           [0.8050679561122701]
# f1_score_weighted                                  [0.8348167525511716]
# AUC_macro                                          [0.8905893690541854]
# matthews_correlation                              [0.42703043994844503]
# recall_score_micro                                 [0.8050679561122701]
# average_precision_score_macro                      [0.7534779916734134]
# AUC_micro                                          [0.8881604603432992]
# average_precision_score_weighted                   [0.9326961946040194]
# f1_score_macro                                        [0.6773148498233]
# balanced_accuracy                                  [0.7967870928685202]
# log_loss                                          [0.49715986720923255]
# f1_score_micro                                     [0.8050679561122701]
# norm_macro_recall                                  [0.5935741857370405]
# recall_score_weighted                              [0.8050679561122701]
# precision_score_macro                              [0.6536232234850076]
#
#                                  366f1870-b3d9-40dc-8b9b-c3686597df46_5
# AUC_weighted                                        [0.855022510666619]
# recall_score_macro                                 [0.7535202845330716]
# precision_score_weighted                           [0.8844710166105174]
# average_precision_score_micro                      [0.8435081877766314]
# precision_score_micro                              [0.7609096797215376]
# weighted_accuracy                                  [0.7627410563006088]
# accuracy                                           [0.7609096797215376]
# f1_score_weighted                                  [0.8003197577208865]
# AUC_macro                                          [0.8550225106666188]
# matthews_correlation                               [0.3532547124932112]
# recall_score_micro                                 [0.7609096797215376]
# average_precision_score_macro                      [0.7214358768185488]
# AUC_micro                                          [0.8600710268961089]
# average_precision_score_weighted                    [0.920056542614658]
# f1_score_macro                                     [0.6306583818896977]
# balanced_accuracy                                  [0.7535202845330716]
# log_loss                                           [0.5174359198196187]
# f1_score_micro                                     [0.7609096797215376]
# norm_macro_recall                                  [0.5070405690661431]
# recall_score_weighted                              [0.7609096797215376]
# precision_score_macro                               [0.623270840552791]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/366f1870-b3d9-40dc-8b9b-c3686597df46/model_data
# Downloaded azureml/366f1870-b3d9-40dc-8b9b-c3686597df46/model_data, 1 files out of an estimated total of 1

# %%
import pickle
import joblib

with open(best_model_output._path_on_datastore, "rb" ) as f:
    print(f)
    # best_model = pickle.load(f)
# best_model
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-22-9692b54b2089> in <module>
#       3
#       4 with open(best_model_output._path_on_datastore, "rb" ) as f:
# ----> 5     best_model = joblib.load(f)
#       6     print(f)
#       7     # best_model = pickle.load(f)
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     593         filename = getattr(fobj, 'name', '')
#     594         with _read_fileobject(fobj, filename, mmap_mode) as fobj:
# --> 595             obj = _unpickle(fobj)
#     596     else:
#     597         with open(filename, 'rb') as f:
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/joblib/numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     527     obj = None
#     528     try:
# --> 529         obj = unpickler.load()
#     530         if unpickler.compat_mode:
#     531             warnings.warn("The file '%s' has been generated with a "
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/pickle.py in load(self)
#    1086                     raise EOFError
#    1087                 assert isinstance(key, bytes_types)
# -> 1088                 dispatch[key[0]](self)
#    1089         except _Stop as stopinst:
#    1090             return stopinst.value
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/joblib/numpy_pickle.py in load_build(self)
#     340         NDArrayWrapper is used for backward compatibility with joblib <= 0.9.
#     341         """
# --> 342         Unpickler.load_build(self)
#     343
#     344         # For backward compatibility, we support NDArrayWrapper objects.
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/pickle.py in load_build(self)
#    1550         setstate = getattr(inst, "__setstate__", None)
#    1551         if setstate is not None:
# -> 1552             setstate(state)
#    1553             return
#    1554         slotstate = None
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/xgboost/core.py in __setstate__(self, state)
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#
# XGBoostError: [16:16:35] ../src/learner.cc:922: Check failed: header == serialisation_header_:
#
#   If you are loading a serialized model (like pickle in Python) generated by older
#   XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version.  There's a simple script for helping
#   the process. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for reference to the script, and more details about differences between saving model and
#   serializing.
#
#
# Stack trace:
#   [bt] (0) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x8d264) [0x7fe1d11e4264]
#   [bt] (1) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x1bd2c1) [0x7fe1d13142c1]
#   [bt] (2) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(XGBoosterUnserializeFromBuffer+0x4d) [0x7fe1d11d52dd]
#   [bt] (3) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/lib-dynload/../../libffi.so.6(ffi_call_unix64+0x4c) [0x7fe36971cec0]
#   [bt] (4) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/lib-dynload/../../libffi.so.6(ffi_call+0x22d) [0x7fe36971c87d]
#   [bt] (5) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(_ctypes_callproc+0x2ce) [0x7fe36a85aede]
#   [bt] (6) /home/donjude/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(+0x12914) [0x7fe36a85b914]
#   [bt] (7) /home/donjude/.pyenv/versions/miniconda3-4.7.12/bin/python(_PyObject_FastCallKeywords+0x49b) [0x55c2b78798fb]
#   [bt] (8) /home/donjude/.pyenv/versions/miniconda3-4.7.12/bin/python(_PyEval_EvalFrameDefault+0x52f8) [0x55c2b78dd6e8]

# %%
best_model.steps

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
# Ensure that the workspace is once again available
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')

# %%
# NOTE: update these to match your existing experiment name and a previous experiment
experiment_name = 'ml-bike-experiment-1'
project_folder = './pipeline-bike-project'

experiment = Experiment(ws, experiment_name)
experiment

# %%
from azureml.pipeline.core import PipelineRun

run_id = "78e729c3-4746-417f-ad9a-abe970f4966f"
pipeline_run = PipelineRun(experiment, run_id)

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bikesharing Train", description="Training bikesharing pipeline", version="1.0")

published_pipeline

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-bike-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-bike-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
